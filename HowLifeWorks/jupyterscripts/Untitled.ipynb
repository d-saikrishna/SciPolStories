# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\dskcy\DataStories\HowLifeWorks\static\How_life_works_comments_with_hierarchy.csv")

# %%
df.Source.value_counts()
# Out:
# Source
# DNA              64
# Protein          44
# RNA              21
# Phenotype        19
# Environment      11
# Transcription     9
# Other             4
# Name: count, dtype: int64

# %%
df.Target.value_counts()
# Out:
# Target
# Phenotype        64
# Protein          33
# DNA              27
# Transcription    18
# RNA              15
# Other            13
# Environment       1
# Translation       1
# Name: count, dtype: int64

# %%
df.Target.isnull().sum()
# Out:
# 1

# %%
df[~df.Source.isnull()].to_csv(r"C:\Users\dskcy\DataStories\HowLifeWorks\static\How_life_works_comments_with_hierarchy.csv")

# %%
df
# Out:
#      Text_id                                               Text  Category  \
# 0        NaN  The hereditary process and the gradual evoluti...     Dogma
# 1        NaN  ... “gene action,” matter comes to life. As th...     Dogma
# 2        NaN  “The approach of genetics,” said biologist Dav...     Dogma
# 3        NaN  Genes are bits of DNA in our chromosomes that ...     Dogma
# 4        NaN  We inherit a blueprint for ourselves from our ...     Dogma
# ..       ...                                                ...       ...
# 168      NaN  To put it another way: the disease results fro...  un-dogma
# 169      NaN  But the effect of carrying the “cystic fibrosi...  un-dogma
# 170      NaN  But that still doesn’t mean SRY is either nece...  un-dogma
# 171      NaN  in an intersection between the mutations that ...  un-dogma
# 172      NaN  Among the many varied roles that the Wnt prote...  un-dogma
#
#               entity entity_ID Priority        Source     Target  \
# ...
